# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c9221920-3434-4d64-bee6-28929b001062" name="files[]" multiple disabled />
#      <output id="result-c9221920-3434-4d64-bee6-28929b001062">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv
# {'Iris.csv': b'Sepal Length (in cm),Sepal Width in (cm),Petal length (in cm),Petal width (in cm),Class\r\n5.1,3.5,1.4,0.2,Iris-setosa\r\n4.9,3,1.4,0.2,Iris-setosa\r\n4.7,3.2,1.3,0.2,Iris-setosa\r\n4.6,3.1,1.5,0.2,Iris-setosa\r\n5,3.6,1.4,0.2,Iris-setosa\r\n5.4,3.9,1.7,0.4,Iris-setosa\r\n4.6,3.4,1.4,0.3,Iris-setosa\r\n5,3.4,1.5,0.2,Iris-setosa\r\n4.4,2.9,1.4,0.2,Iris-setosa\r\n4.9,3.1,1.5,0.1,Iris-setosa\r\n5.4,3.7,1.5,0.2,Iris-setosa\r\n4.8,3.4,1.6,0.2,Iris-setosa\r\n4.8,3,1.4,0.1,Iris-setosa\r\n4.3,3,1.1,0.1,Iris-setosa\r\n5.8,4,1.2,0.2,Iris-setosa\r\n5.7,4.4,1.5,0.4,Iris-setosa\r\n5.4,3.9,1.3,0.4,Iris-setosa\r\n5.1,3.5,1.4,0.3,Iris-setosa\r\n5.7,3.8,1.7,0.3,Iris-setosa\r\n5.1,3.8,1.5,0.3,Iris-setosa\r\n5.4,3.4,1.7,0.2,Iris-setosa\r\n5.1,3.7,1.5,0.4,Iris-setosa\r\n4.6,3.6,1,0.2,Iris-setosa\r\n5.1,3.3,1.7,0.5,Iris-setosa\r\n4.8,3.4,1.9,0.2,Iris-setosa\r\n5,3,1.6,0.2,Iris-setosa\r\n5,3.4,1.6,0.4,Iris-setosa\r\n5.2,3.5,1.5,0.2,Iris-setosa\r\n5.2,3.4,1.4,0.2,Iris-setosa\r\n4.7,3.2,1.6,0.2,Iris-setosa\r\n4.8,3.1,1.6,0.2,Iris-setosa\r\n5.4,3.4,1.5,0.4,Iris-setosa\r\n5.2,4.1,1.5,0.1,Iris-setosa\r\n5.5,4.2,1.4,0.2,Iris-setosa\r\n4.9,3.1,1.5,0.1,Iris-setosa\r\n5,3.2,1.2,0.2,Iris-setosa\r\n5.5,3.5,1.3,0.2,Iris-setosa\r\n4.9,3.1,1.5,0.1,Iris-setosa\r\n4.4,3,1.3,0.2,Iris-setosa\r\n5.1,3.4,1.5,0.2,Iris-setosa\r\n5,3.5,1.3,0.3,Iris-setosa\r\n4.5,2.3,1.3,0.3,Iris-setosa\r\n4.4,3.2,1.3,0.2,Iris-setosa\r\n5,3.5,1.6,0.6,Iris-setosa\r\n5.1,3.8,1.9,0.4,Iris-setosa\r\n4.8,3,1.4,0.3,Iris-setosa\r\n5.1,3.8,1.6,0.2,Iris-setosa\r\n4.6,3.2,1.4,0.2,Iris-setosa\r\n5.3,3.7,1.5,0.2,Iris-setosa\r\n5,3.3,1.4,0.2,Iris-setosa\r\n7,3.2,4.7,1.4,Iris-versicolor\r\n6.4,3.2,4.5,1.5,Iris-versicolor\r\n6.9,3.1,4.9,1.5,Iris-versicolor\r\n5.5,2.3,4,1.3,Iris-versicolor\r\n6.5,2.8,4.6,1.5,Iris-versicolor\r\n5.7,2.8,4.5,1.3,Iris-versicolor\r\n6.3,3.3,4.7,1.6,Iris-versicolor\r\n4.9,2.4,3.3,1,Iris-versicolor\r\n6.6,2.9,4.6,1.3,Iris-versicolor\r\n5.2,2.7,3.9,1.4,Iris-versicolor\r\n5,2,3.5,1,Iris-versicolor\r\n5.9,3,4.2,1.5,Iris-versicolor\r\n6,2.2,4,1,Iris-versicolor\r\n6.1,2.9,4.7,1.4,Iris-versicolor\r\n5.6,2.9,3.6,1.3,Iris-versicolor\r\n6.7,3.1,4.4,1.4,Iris-versicolor\r\n5.6,3,4.5,1.5,Iris-versicolor\r\n5.8,2.7,4.1,1,Iris-versicolor\r\n6.2,2.2,4.5,1.5,Iris-versicolor\r\n5.6,2.5,3.9,1.1,Iris-versicolor\r\n5.9,3.2,4.8,1.8,Iris-versicolor\r\n6.1,2.8,4,1.3,Iris-versicolor\r\n6.3,2.5,4.9,1.5,Iris-versicolor\r\n6.1,2.8,4.7,1.2,Iris-versicolor\r\n6.4,2.9,4.3,1.3,Iris-versicolor\r\n6.6,3,4.4,1.4,Iris-versicolor\r\n6.8,2.8,4.8,1.4,Iris-versicolor\r\n6.7,3,5,1.7,Iris-versicolor\r\n6,2.9,4.5,1.5,Iris-versicolor\r\n5.7,2.6,3.5,1,Iris-versicolor\r\n5.5,2.4,3.8,1.1,Iris-versicolor\r\n5.5,2.4,3.7,1,Iris-versicolor\r\n5.8,2.7,3.9,1.2,Iris-versicolor\r\n6,2.7,5.1,1.6,Iris-versicolor\r\n5.4,3,4.5,1.5,Iris-versicolor\r\n6,3.4,4.5,1.6,Iris-versicolor\r\n6.7,3.1,4.7,1.5,Iris-versicolor\r\n6.3,2.3,4.4,1.3,Iris-versicolor\r\n5.6,3,4.1,1.3,Iris-versicolor\r\n5.5,2.5,4,1.3,Iris-versicolor\r\n5.5,2.6,4.4,1.2,Iris-versicolor\r\n6.1,3,4.6,1.4,Iris-versicolor\r\n5.8,2.6,4,1.2,Iris-versicolor\r\n5,2.3,3.3,1,Iris-versicolor\r\n5.6,2.7,4.2,1.3,Iris-versicolor\r\n5.7,3,4.2,1.2,Iris-versicolor\r\n5.7,2.9,4.2,1.3,Iris-versicolor\r\n6.2,2.9,4.3,1.3,Iris-versicolor\r\n5.1,2.5,3,1.1,Iris-versicolor\r\n5.7,2.8,4.1,1.3,Iris-versicolor\r\n6.3,3.3,6,2.5,Iris-virginica\r\n5.8,2.7,5.1,1.9,Iris-virginica\r\n7.1,3,5.9,2.1,Iris-virginica\r\n6.3,2.9,5.6,1.8,Iris-virginica\r\n6.5,3,5.8,2.2,Iris-virginica\r\n7.6,3,6.6,2.1,Iris-virginica\r\n4.9,2.5,4.5,1.7,Iris-virginica\r\n7.3,2.9,6.3,1.8,Iris-virginica\r\n6.7,2.5,5.8,1.8,Iris-virginica\r\n7.2,3.6,6.1,2.5,Iris-virginica\r\n6.5,3.2,5.1,2,Iris-virginica\r\n6.4,2.7,5.3,1.9,Iris-virginica\r\n6.8,3,5.5,2.1,Iris-virginica\r\n5.7,2.5,5,2,Iris-virginica\r\n5.8,2.8,5.1,2.4,Iris-virginica\r\n6.4,3.2,5.3,2.3,Iris-virginica\r\n6.5,3,5.5,1.8,Iris-virginica\r\n7.7,3.8,6.7,2.2,Iris-virginica\r\n7.7,2.6,6.9,2.3,Iris-virginica\r\n6,2.2,5,1.5,Iris-virginica\r\n6.9,3.2,5.7,2.3,Iris-virgini ...

# %%
import pandas as pd

# %%
Iris = pd.read_csv('Iris.csv')
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
print(Iris.head(10))
print(Iris.tail(10))
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
# 5                   5.4                  3.9  ...                  0.4  Iris-setosa
# 6                   4.6                  3.4  ...                  0.3  Iris-setosa
# 7                   5.0                  3.4  ...                  0.2  Iris-setosa
# 8                   4.4                  2.9  ...                  0.2  Iris-setosa
# 9                   4.9                  3.1  ...                  0.1  Iris-setosa
#
# [10 rows x 5 columns]
#      Sepal Length (in cm)  ...           Class
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.columns
# Out:
# Index(['Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
#        'Petal width (in cm)', 'Class'],
#       dtype='object')

# %%
Iris.set_index(['Sepal Length (in cm)'])
# Out:
#                       Sepal Width in (cm)  ...           Class
# Sepal Length (in cm)                       ...
# 5.1                                   3.5  ...     Iris-setosa
# 4.9                                   3.0  ...     Iris-setosa
# 4.7                                   3.2  ...     Iris-setosa
# 4.6                                   3.1  ...     Iris-setosa
# 5.0                                   3.6  ...     Iris-setosa
# 5.4                                   3.9  ...     Iris-setosa
# 4.6                                   3.4  ...     Iris-setosa
# 5.0                                   3.4  ...     Iris-setosa
# 4.4                                   2.9  ...     Iris-setosa
# 4.9                                   3.1  ...     Iris-setosa
# 5.4                                   3.7  ...     Iris-setosa
# 4.8                                   3.4  ...     Iris-setosa
# 4.8                                   3.0  ...     Iris-setosa
# 4.3                                   3.0  ...     Iris-setosa
# 5.8                                   4.0  ...     Iris-setosa
# 5.7                                   4.4  ...     Iris-setosa
# 5.4                                   3.9  ...     Iris-setosa
# 5.1                                   3.5  ...     Iris-setosa
# 5.7                                   3.8  ...     Iris-setosa
# 5.1                                   3.8  ...     Iris-setosa
# 5.4                                   3.4  ...     Iris-setosa
# 5.1                                   3.7  ...     Iris-setosa
# 4.6                                   3.6  ...     Iris-setosa
# 5.1                                   3.3  ...     Iris-setosa
# 4.8                                   3.4  ...     Iris-setosa
# 5.0                                   3.0  ...     Iris-setosa
# 5.0                                   3.4  ...     Iris-setosa
# 5.2                                   3.5  ...     Iris-setosa
# 5.2                                   3.4  ...     Iris-setosa
# 4.7                                   3.2  ...     Iris-setosa
# ...                                   ...  ...             ...
# 6.9                                   3.2  ...  Iris-virginica
# 5.6                                   2.8  ...  Iris-virginica
# 7.7                                   2.8  ...  Iris-virginica
# 6.3                                   2.7  ...  Iris-virginica
# 6.7                                   3.3  ...  Iris-virginica
# 7.2                                   3.2  ...  Iris-virginica
# 6.2                                   2.8  ...  Iris-virginica
# 6.1                                   3.0  ...  Iris-virginica
# 6.4                                   2.8  ...  Iris-virginica
# 7.2                                   3.0  ...  Iris-virginica
# 7.4                                   2.8  ...  Iris-virginica
# 7.9                                   3.8  ...  Iris-virginica
# 6.4                                   2.8  ...  Iris-virginica
# 6.3                                   2.8  ...  Iris-virginica
# 6.1                                   2.6  ...  Iris-virginica
# 7.7                                   3.0  ...  Iris-virginica
# 6.3                                   3.4  ...  Iris-virginica
# 6.4                                   3.1  ...  Iris-virginica
# 6.0                                   3.0  ...  Iris-virginica
# 6.9                                   3.1  ...  Iris-virginica
# 6.7                                   3.1  ...  Iris-virginica
# 6.9                                   3.1  ...  Iris-virginica
# 5.8                                   2.7  ...  Iris-virginica
# 6.8                                   3.2  ...  Iris-virginica
# 6.7                                   3.3  ...  Iris-virginica
# 6.7                                   3.0  ...  Iris-virginica
# 6.3                                   2.5  ...  Iris-virginica
# 6.5                                   3.0  ...  Iris-virginica
# 6.2                                   3.4  ...  Iris-virginica
# 5.9                                   3.0  ...  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris[['Sepal Width in (cm)', 'Sepal Length (in cm)']].head(10)
# Out:
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[Iris.Class == "Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                    5.1                  3.5  ...                  0.2  Iris-setosa
# 1                    4.9                  3.0  ...                  0.2  Iris-setosa
# 2                    4.7                  3.2  ...                  0.2  Iris-setosa
# 3                    4.6                  3.1  ...                  0.2  Iris-setosa
# 4                    5.0                  3.6  ...                  0.2  Iris-setosa
# 5                    5.4                  3.9  ...                  0.4  Iris-setosa
# 6                    4.6                  3.4  ...                  0.3  Iris-setosa
# 7                    5.0                  3.4  ...                  0.2  Iris-setosa
# 8                    4.4                  2.9  ...                  0.2  Iris-setosa
# 9                    4.9                  3.1  ...                  0.1  Iris-setosa
# 10                   5.4                  3.7  ...                  0.2  Iris-setosa
# 11                   4.8                  3.4  ...                  0.2  Iris-setosa
# 12                   4.8                  3.0  ...                  0.1  Iris-setosa
# 13                   4.3                  3.0  ...                  0.1  Iris-setosa
# 14                   5.8                  4.0  ...                  0.2  Iris-setosa
# 15                   5.7                  4.4  ...                  0.4  Iris-setosa
# 16                   5.4                  3.9  ...                  0.4  Iris-setosa
# 17                   5.1                  3.5  ...                  0.3  Iris-setosa
# 18                   5.7                  3.8  ...                  0.3  Iris-setosa
# 19                   5.1                  3.8  ...                  0.3  Iris-setosa
# 20                   5.4                  3.4  ...                  0.2  Iris-setosa
# 21                   5.1                  3.7  ...                  0.4  Iris-setosa
# 22                   4.6                  3.6  ...                  0.2  Iris-setosa
# 23                   5.1                  3.3  ...                  0.5  Iris-setosa
# 24                   4.8                  3.4  ...                  0.2  Iris-setosa
# 25                   5.0                  3.0  ...                  0.2  Iris-setosa
# 26                   5.0                  3.4  ...                  0.4  Iris-setosa
# 27                   5.2                  3.5  ...                  0.2  Iris-setosa
# 28                   5.2                  3.4  ...                  0.2  Iris-setosa
# 29                   4.7                  3.2  ...                  0.2  Iris-setosa
# 30                   4.8                  3.1  ...                  0.2  Iris-setosa
# 31                   5.4                  3.4  ...                  0.4  Iris-setosa
# 32                   5.2                  4.1  ...                  0.1  Iris-setosa
# 33                   5.5                  4.2  ...                  0.2  Iris-setosa
# 34                   4.9                  3.1  ...                  0.1  Iris-setosa
# 35                   5.0                  3.2  ...                  0.2  Iris-setosa
# 36                   5.5                  3.5  ...                  0.2  Iris-setosa
# 37                   4.9                  3.1  ...                  0.1  Iris-setosa
# 38                   4.4                  3.0  ...                  0.2  Iris-setosa
# 39                   5.1                  3.4  ...                  0.2  Iris-setosa
# 40                   5.0                  3.5  ...                  0.3  Iris-setosa
# 41                   4.5                  2.3  ...                  0.3  Iris-setosa
# 42                   4.4                  3.2  ...                  0.2  Iris-setosa
# 43                   5.0                  3.5  ...                  0.6  Iris-setosa
# 44                   5.1                  3.8  ...                  0.4  Iris-setosa
# 45                   4.8                  3.0  ...                  0.3  Iris-setosa
# 46                   5.1                  3.8  ...                  0.2  Iris-setosa
# 47                   4.6                  3.2  ...                  0.2  Iris-setosa
# 48                   5.3                  3.7  ...                  0.2  Iris-setosa
# 49                   5.0                  3.3  ...                  0.2  Iris-setosa
#
# [50 rows x 5 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra'] = Iris['Sepal Length (in cm)'] * Iris['Sepal Length (in cm)']

# %%
Iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...        Class  SepalExtra
# 0                   5.1                  3.5  ...  Iris-setosa       26.01
# 1                   4.9                  3.0  ...  Iris-setosa       24.01
# 2                   4.7                  3.2  ...  Iris-setosa       22.09
# 3                   4.6                  3.1  ...  Iris-setosa       21.16
# 4                   5.0                  3.6  ...  Iris-setosa       25.00
# 5                   5.4                  3.9  ...  Iris-setosa       29.16
# 6                   4.6                  3.4  ...  Iris-setosa       21.16
# 7                   5.0                  3.4  ...  Iris-setosa       25.00
# 8                   4.4                  2.9  ...  Iris-setosa       19.36
# 9                   4.9                  3.1  ...  Iris-setosa       24.01
#
# [10 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
print("Mean:\n",Iris.mean(numeric_only=1),
      "\n\nVariance:\n",Iris.var(numeric_only=1))

# getting same results with Iris.mean()
# Out:
# Mean:
#  Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              34.825667
# dtype: float64
#
# Variance:
#  Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              98.440548
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def print_two_numbers(a,b):
  print("Sepal Length (in cm):", a,
        "\nSepal Width in (cm):", b)

print_two_numbers(Iris.loc[4,'Sepal Length (in cm)'], Iris.loc[4,'Sepal Width in (cm)'])
# Out:
# Sepal Length (in cm): 5.0
# Sepal Width in (cm): 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
Iris.max(numeric_only=1)
# Out:
# Sepal Length (in cm)     7.90
# Sepal Width in (cm)      4.40
# Petal length (in cm)     6.90
# Petal width (in cm)      2.50
# SepalExtra              62.41
# dtype: float64

# %%
Iris.min(numeric_only=1)
# Out:
# Sepal Length (in cm)     4.30
# Sepal Width in (cm)      2.00
# Petal length (in cm)     1.00
# Petal width (in cm)      0.10
# SepalExtra              18.49
# dtype: float64

# %%
Iris.max(numeric_only=1) - Iris.min(numeric_only=1)
# Out:
# Sepal Length (in cm)     3.60
# Sepal Width in (cm)      2.40
# Petal length (in cm)     5.90
# Petal width (in cm)      2.40
# SepalExtra              43.92
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values(by = ['Petal width (in cm)'])
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  ...           Class  SepalExtra
# 32                    5.2                  4.1  ...     Iris-setosa       27.04
# 13                    4.3                  3.0  ...     Iris-setosa       18.49
# 37                    4.9                  3.1  ...     Iris-setosa       24.01
# 9                     4.9                  3.1  ...     Iris-setosa       24.01
# 12                    4.8                  3.0  ...     Iris-setosa       23.04
# 34                    4.9                  3.1  ...     Iris-setosa       24.01
# 0                     5.1                  3.5  ...     Iris-setosa       26.01
# 27                    5.2                  3.5  ...     Iris-setosa       27.04
# 28                    5.2                  3.4  ...     Iris-setosa       27.04
# 29                    4.7                  3.2  ...     Iris-setosa       22.09
# 30                    4.8                  3.1  ...     Iris-setosa       23.04
# 33                    5.5                  4.2  ...     Iris-setosa       30.25
# 36                    5.5                  3.5  ...     Iris-setosa       30.25
# 38                    4.4                  3.0  ...     Iris-setosa       19.36
# 39                    5.1                  3.4  ...     Iris-setosa       26.01
# 42                    4.4                  3.2  ...     Iris-setosa       19.36
# 46                    5.1                  3.8  ...     Iris-setosa       26.01
# 47                    4.6                  3.2  ...     Iris-setosa       21.16
# 48                    5.3                  3.7  ...     Iris-setosa       28.09
# 49                    5.0                  3.3  ...     Iris-setosa       25.00
# 25                    5.0                  3.0  ...     Iris-setosa       25.00
# 24                    4.8                  3.4  ...     Iris-setosa       23.04
# 35                    5.0                  3.2  ...     Iris-setosa       25.00
# 3                     4.6                  3.1  ...     Iris-setosa       21.16
# 2                     4.7                  3.2  ...     Iris-setosa       22.09
# 7                     5.0                  3.4  ...     Iris-setosa       25.00
# 8                     4.4                  2.9  ...     Iris-setosa       19.36
# 10                    5.4                  3.7  ...     Iris-setosa       29.16
# 4                     5.0                  3.6  ...     Iris-setosa       25.00
# 11                    4.8                  3.4  ...     Iris-setosa       23.04
# ..                    ...                  ...  ...             ...         ...
# 111                   6.4                  2.7  ...  Iris-virginica       40.96
# 121                   5.6                  2.8  ...  Iris-virginica       31.36
# 122                   7.7                  2.8  ...  Iris-virginica       59.29
# 147                   6.5                  3.0  ...  Iris-virginica       42.25
# 113                   5.7                  2.5  ...  Iris-virginica       32.49
# 131                   7.9                  3.8  ...  Iris-virginica       62.41
# 110                   6.5                  3.2  ...  Iris-virginica       42.25
# 139                   6.9                  3.1  ...  Iris-virginica       47.61
# 102                   7.1                  3.0  ...  Iris-virginica       50.41
# 112                   6.8                  3.0  ...  Iris-virginica       46.24
# 105                   7.6                  3.0  ...  Iris-virginica       57.76
# 124                   6.7                  3.3  ...  Iris-virginica       44.89
# 128                   6.4                  2.8  ...  Iris-virginica       40.96
# 117                   7.7                  3.8  ...  Iris-virginica       59.29
# 132                   6.4                  2.8  ...  Iris-virginica       40.96
# 104                   6.5                  3.0  ...  Iris-virginica       42.25
# 120                   6.9                  3.2  ...  Iris-virginica       47.61
# 115                   6.4                  3.2  ...  Iris-virginica       40.96
# 148                   6.2                  3.4  ...  Iris-virginica       38.44
# 141                   6.9                  3.1  ...  Iris-virginica       47.61
# 143                   6.8                  3.2  ...  Iris-virginica       46.24
# 145                   6.7                  3.0  ...  Iris-virginica       44.89
# 118                   7.7                  2.6  ...  Iris-virginica       59.29
# 135                   7.7                  3.0  ...  Iris-virginica       59.29
# 136                   6.3                  3.4  ...  Iris-virginica       39.69
# 140                   6.7                  3.1  ...  Iris-virginica       44.89
# 114                   5.8                  2.8  ...  Iris-virginica       33.64
# 100                   6.3                  3.3  ...  Iris-virginica       39.69
# 144                   6.7                  3.3  ...  Iris-virginica       44.89
# 109                   7.2                  3.6  ...  Iris-virginica       51.84
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop('SepalExtra', axis=1, inplace=True)
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[:10,:3]

# %%
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
# Pandas already imported bove

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
# Run this cell only if you are using Google colab
# Skip this cell if you are using jupyter notebook
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-214f907b-9cc1-44f0-973f-268db45090d6" name="files[]" multiple disabled />
#      <output id="result-214f907b-9cc1-44f0-973f-268db45090d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HR.csv to HR.csv
# {'HR.csv': b'Individual,Attrition,Age,BusinessTravel,DailyRate,Department,DistanceFromHome,Education,EducationField,EmployeeCount,EmployeeNumber,EnvironmentSatisfaction,Gender,HourlyRate,JobInvolvement,JobLevel,JobRole,JobSatisfaction,MaritalStatus,MonthlyIncome,MonthlyRate,NumCompaniesWorked,OverTime,PercentSalaryHike,PerformanceRating,RelationshipSatisfaction,StandardHours,StockOptionLevel,TotalWorkingYears,TrainingTimesLastYear,WorkLifeBalance,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager\r\nInd1,Yes,41,1,1102,1,1,2,1,1,1,2,2,94,3,2,1,4,1,5993,19479,8,1,11,3,1,80,0,8,0,1,6,4,0,5\r\nInd2,No,49,2,279,2,8,1,1,1,2,3,1,61,2,2,2,2,2,5130,24907,1,2,23,4,4,80,1,10,3,3,10,7,1,7\r\nInd3,Yes,37,1,1373,2,2,2,6,1,4,4,1,92,2,1,3,3,1,2090,2396,6,1,15,3,2,80,0,7,3,3,0,0,0,0\r\nInd4,No,33,2,1392,2,3,4,1,1,5,4,2,56,3,1,2,3,2,2909,23159,1,1,11,3,3,80,0,8,3,3,8,7,3,0\r\nInd5,No,27,1,591,2,2,1,2,1,7,1,1,40,3,1,3,2,2,3468,16632,9,2,12,3,4,80,1,6,3,3,2,2,2,2\r\nInd6,No,32,2,1005,2,2,2,1,1,8,4,1,79,3,1,3,4,1,3068,11864,0,2,13,3,3,80,0,8,2,2,7,7,3,6\r\nInd7,No,59,1,1324,2,3,3,2,1,10,3,2,81,4,1,3,1,2,2670,9964,4,1,20,4,1,80,3,12,3,2,1,0,0,0\r\nInd8,No,30,1,1358,2,24,1,1,1,11,4,1,67,3,1,3,3,3,2693,13335,1,2,22,4,2,80,1,1,2,3,1,0,0,0\r\nInd9,No,38,2,216,2,23,3,1,1,12,4,1,44,2,3,4,3,1,9526,8787,0,2,21,4,2,80,0,10,2,3,9,7,1,8\r\nInd10,No,36,1,1299,2,27,3,2,1,13,3,1,94,3,2,5,3,2,5237,16577,6,2,13,3,2,80,2,17,3,2,7,7,7,7\r\nInd11,No,35,1,809,2,16,3,2,1,14,1,1,84,4,1,3,2,2,2426,16479,0,2,13,3,3,80,1,6,5,3,5,4,0,3\r\nInd12,No,29,1,153,2,15,2,1,1,15,4,2,49,2,2,3,3,1,4193,12682,0,1,12,3,4,80,0,10,3,3,9,5,0,8\r\nInd13,No,31,1,670,2,26,1,1,1,16,1,1,31,3,1,2,3,3,2911,15170,1,2,17,3,4,80,1,5,1,2,5,2,4,3\r\nInd14,No,34,1,1346,2,19,2,2,1,18,2,1,93,3,1,3,4,3,2661,8758,0,2,11,3,3,80,1,3,2,3,2,2,1,2\r\nInd15,Yes,28,1,103,2,24,3,1,1,19,3,1,50,2,1,3,3,1,2028,12947,5,1,14,3,2,80,0,6,4,3,4,2,0,3\r\nInd16,No,29,1,1389,2,21,4,1,1,20,2,2,51,4,3,4,1,3,9980,10195,1,2,11,3,3,80,1,10,1,3,10,9,8,8\r\nInd17,No,32,1,334,2,5,2,1,1,21,1,1,80,4,1,2,2,3,3298,15053,0,1,12,3,4,80,2,7,5,2,6,2,0,5\r\nInd18,No,22,3,1123,2,16,2,2,1,22,4,1,96,4,1,3,4,3,2935,7324,1,1,13,3,2,80,2,1,2,2,1,0,0,0\r\nInd19,No,53,1,1219,1,2,4,1,1,23,1,2,78,2,4,6,4,2,15427,22021,2,2,16,3,3,80,0,31,3,3,25,8,3,7\r\nInd20,No,38,1,371,2,2,3,1,1,24,4,1,45,3,1,2,4,1,3944,4306,5,1,11,3,3,80,0,6,3,3,3,2,1,2\r\nInd21,No,24,3,673,2,11,2,6,1,26,1,2,96,4,2,4,3,3,4011,8232,0,2,18,3,4,80,1,5,5,2,4,2,1,3\r\nInd22,Yes,36,1,1218,1,9,4,1,1,27,3,1,82,2,1,7,1,1,3407,6986,7,2,23,4,2,80,0,10,4,3,5,3,0,3\r\nInd23,No,34,1,419,2,7,4,1,1,28,1,2,53,3,3,8,2,1,11994,21293,0,2,11,3,3,80,0,13,4,3,12,6,2,11\r\nInd24,No,21,1,391,2,15,2,1,1,30,3,1,96,3,1,2,4,1,1232,19281,1,2,14,3,4,80,0,0,6,3,0,0,0,0\r\nInd25,Yes,34,1,699,2,6,1,2,1,31,2,1,83,3,1,2,1,1,2960,17102,2,2,11,3,3,80,0,8,2,3,4,2,1,3\r\nInd26,No,53,1,1282,2,5,3,6,1,32,3,2,58,3,5,6,3,3,19094,10735,4,2,11,3,4,80,1,26,3,2,14,13,4,8\r\nInd27,Yes,32,2,1125,2,16,1,1,1,33,2,2,72,1,1,2,1,1,3919,4681,1,1,22,4,2,80,0,10,5,3,10,2,6,7\r\nInd28,No,42,1,691,1,8,4,3,1,35,3,1,48,3,2,1,2,2,6825,21173,0,2,11,3,4,80,1,10,2,3,9,7,4,2\r\nInd29,No,44,1,477,2,7,4,2,1,36,1,2,42,2,3,5,4,2,10248,2094,3,2,14,3,4,80,1,24,4,3,22,6,5,17\r\nInd30,No,46,1,705,1,2,4,3,1,38,2,2,83,3,5,6,1,1,18947,22822,3,2,12,3,4,80,0,22,2,2,2,2,2,1\r\nInd31,No,33,1,924,2,2,3,2,1,39,3,1,78,3,1,3,4,1,2496,6670,4,2,11,3,4,80,0,7,3,3,1,1,0,0\r\nInd32,No,44,1,1459,2,10,4,6,1,40,4,1,41,3,2,5,4,2,6465,19121,2,1,13,3,4,80,0,9,5,4,4,2,1,3\r\nInd33,No,30,1,125,2,9,2,2,1,41,4,1,83,2,1,3,3,1,2206,16117,1,2,13,3,1,80,0,10,5,3,10,0,1,8\r\nInd34,Yes,39,1,895,1,5,3,4,1,42,4,1,56,3,2,7,4,2,2086,3335,3,2,14,3,3,80,1,19,6,4,1,0,0,0\r\nInd35,Yes,24,1,813,2,1,3,2,1,45,2,1,61,3,1,2,4,2,2293,3020,2,1,16,3,1,80,1,6,2,2,2,0,2,0\r\nInd36,No,43,1,1273,2,2,2,2,1,46,4,2,72,4,1,2,3,3,2645,21923,1,2,12,3,4,80,2,6,3,2,5,3,1,4\r\nInd37,Yes,50,1,869,1,3,2,3,1,47,1,1,86,2,1,7,3,2,2683,3810,1,1,14,3,3,80,0,3,2,3,3,2,0,2\r\nInd38,No,35,1,890,1,2 ...

# %%
#HR data file I downloaded was in CSV format, earlier it was showing .txt, with \t I could get the same resulults like below
dataset = pd.read_csv('HR.csv')
dataset.head()
# Out:
#   Individual Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0       Ind1       Yes  ...                        0                     5
# 1       Ind2        No  ...                        1                     7
# 2       Ind3       Yes  ...                        0                     0
# 3       Ind4        No  ...                        3                     0
# 4       Ind5        No  ...                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
print("Total Columns:",len(dataset.columns))
# Out:
# Total Columns: 35

# %%
print("Total Rows:", len(dataset))
# Out:
# Total Rows: 1470

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
dataset.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
dataset.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  ...  Education  EducationField  EmployeeCount
# 0      41               1       1102  ...          2               1              1
# 1      49               2        279  ...          1               1              1
# 2      37               1       1373  ...          2               6              1
# 3      33               2       1392  ...          4               1              1
# 4      27               1        591  ...          1               2              1
# 5      32               2       1005  ...          2               1              1
# 6      59               1       1324  ...          3               2              1
# 7      30               1       1358  ...          1               1              1
# 8      38               2        216  ...          3               1              1
# 9      36               1       1299  ...          3               2              1
# 10     35               1        809  ...          3               2              1
# 11     29               1        153  ...          2               1              1
# 12     31               1        670  ...          1               1              1
# 13     34               1       1346  ...          2               2              1
# 14     28               1        103  ...          3               1              1
# 15     29               1       1389  ...          4               1              1
# 16     32               1        334  ...          2               1              1
# 17     22               3       1123  ...          2               2              1
# 18     53               1       1219  ...          4               1              1
# 19     38               1        371  ...          3               1              1
# 20     24               3        673  ...          2               6              1
# 21     36               1       1218  ...          4               1              1
# 22     34               1        419  ...          4               1              1
# 23     21               1        391  ...          2               1              1
# 24     34               1        699  ...          1               2              1
# 25     53               1       1282  ...          3               6              1
# 26     32               2       1125  ...          1               1              1
# 27     42               1        691  ...          4               3              1
# 28     44               1        477  ...          4               2              1
# 29     46               1        705  ...          4               3              1
# ...   ...             ...        ...  ...        ...             ...            ...
# 1440   36               2        688  ...          2               1              1
# 1441   56               3        667  ...          4               1              1
# 1442   29               1       1092  ...          4               2              1
# 1443   42               1        300  ...          3               1              1
# 1444   56               1        310  ...          2               4              1
# 1445   41               1        582  ...          4               1              1
# 1446   34               1        704  ...          3               3              1
# 1447   36               3        301  ...          4               3              1
# 1448   41               1        930  ...          3               1              1
# 1449   32               1        529  ...          3               4              1
# 1450   35               1       1146  ...          4               1              1
# 1451   38               1        345  ...          2               1              1
# 1452   50               2        878  ...          4               1              1
# 1453   36               1       1120  ...          4               3              1
# 1454   45               1        374  ...          3               1              1
# 1455   40               1       1322  ...          4               1              1
# 1456   35               2       1199  ...          4               1              1
# 1457   40               1       1194  ...          4               2              1
# 1458   35               1        287  ...          4               1              1
# 1459   29               1       1378  ...          2               6              1
# 1460   29               1        468  ...          4               2              1
# 1461   50               1        410  ...          3               3              1
# 1462   39               1        722  ...          1               3              1
# 1463   31               3        325  ...          3               2              1
# 1464   26               1       1167  ...          3               6              1
# 1465   36               2        884  ...          2               2              1
# 1466   39               1        613  ...          1               2              1
# 1467   27               1        155  ...          3               1              1
# 1468   49               2       1023  ...          3               2              1
# 1469   34               1        628  ...          3               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
print("Total Number of 1's:",sum(dataset.Gender == 1))
# Out:
# Total Number of 1's: 882

# %%
print("Total Number of 2's:",sum(dataset.Gender == 2))
# Out:
# Total Number of 2's: 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
Q3 = dataset.Age.quantile(0.75)
print("75th Percentile:",Q3)

Q1 = dataset.Age.quantile(0.25)
print("25th Percentile:",Q1)

IQR = Q3 - Q1
print("Interquartile Range:",IQR)
# Out:
# 75th Percentile: 43.0
# 25th Percentile: 30.0
# Interquartile Range: 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
print("Daily Rate mean:", dataset.DailyRate.mean(),
      "\nDaily Rate median:", dataset.DailyRate.median(),
      "\nDaily Rate variance:", dataset.DailyRate.var())
# Out:
# Daily Rate mean: 802.4857142857143
# Daily Rate median: 802.0
# Daily Rate variance: 162819.59373723628

# %% [markdown]
# # Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)
#
# ### Not Clear with what is expected as output

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(dataset.index, dataset['Attrition'] == 'Yes')
plt.plot(dataset.index, dataset['Attrition'] == 'No')
plt.show()

# %%
plt.bar(dataset['Attrition'], height=1)
plt.show()

# %%
plt.scatter(dataset.index, dataset['Attrition'], c='m')
plt.show()

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
plt.plot(dataset['TotalWorkingYears'], c='b')
plt.show()
